# %% [markdown]
# <a href="https://colab.research.google.com/github/fatinnadzirah21/Python-Pandas-Google-Colaboratory/blob/main/shark_attack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
shark_attack = pd.read_csv("/content/drive/MyDrive/Datasets/shark_attack_cleaned_data - shark_attacks.csv")
shark_attack
# Out:
#        Case Number                  Date  Year        Type         Country  \
# 0       2017.06.11            2017-06-11  2017  Unprovoked       AUSTRALIA
# 1     2017.06.10.b            2017-06-10  2017  Unprovoked       AUSTRALIA
# 2     2017.06.10.a            2017-06-10  2017  Unprovoked             USA
# 3     2017.06.07.R  Reported 07-Jun-2017  2017  Unprovoked  UNITED KINGDOM
# 4       2017.06.04            2017-06-04  2017  Unprovoked             USA
# ...            ...                   ...   ...         ...             ...
# 1152    2008.01.30            2008.01.30  2008    Provoked           JAPAN
# 1153    2008.01.29            2008-01-29  2008  Unprovoked    SOUTH AFRICA
# 1154    2008.01.27            2008-01-27  2008    Provoked       AUSTRALIA
# 1155  2008.01.19.R  Reported 19-Jan-2008  2008     Invalid     NEW ZEALAND
# 1156    2008.01.14            2008-01-14  2008        Boat     NEW ZEALAND
#
# ...

# %%
shark_attack.isna().sum()
# Out:
# Case Number               0
# Date                      0
# Year                      0
# Type                      0
# Country                   0
# Area                      0
# Location                  0
# Activity                  0
# Name                      0
# Sex                       0
# Age                       0
# Injury                    0
# Fatal (Y/N)               0
# Time                      0
# Species                   0
# Investigator or Source    0
# href                      0
# Address                   0
# dtype: int64

# %%
shark_attack[shark_attack.Area.isna()]
# Out:
#        Case Number                   Date  Year          Type  \
# 71    2016.10.13.R             2016-10-13  2016       Invalid
# 91      2016.09.00             2020-09-16  2016       Invalid
# 94      2016.08.27             2016-08-27  2016    Unprovoked
# 113   2016.07.14.R   Reported 14-Jul-2016  2016    Unprovoked
# 135   2016.06.02.a             2016-06-02  2016    Unprovoked
# 160     2016.03.26             2016-03-26  2016      Provoked
# 188     2015.12.19             2015-12-19  2015    Unprovoked
# 190     2015.12.11             2015-12-11  2015    Unprovoked
# 231     2015.09.00             2020-09-15  2015    Unprovoked
# 248     2015.07.22             2015-07-22  2015    Unprovoked
# 270     2015.06.19             2015-06-19  2015    Unprovoked
# 285     2015.05.09             2015-05-09  2015    Unprovoked
# 300     2015.03.21             2015-03-21  2015    Unprovoked
# 306     2015.02.15             2015-02-15  2015          Boat
# ...

# %%
shark_attack = shark_attack.replace(to_replace = np.nan, value = "N/A")

# %%
shark_attack["Address"] = shark_attack.Location + ", " + shark_attack.Area + ", " + shark_attack.Country
shark_attack
# Out:
#        Case Number                  Date  Year        Type         Country  \
# 0       2017.06.11            2017-06-11  2017  Unprovoked       AUSTRALIA
# 1     2017.06.10.b            2017-06-10  2017  Unprovoked       AUSTRALIA
# 2     2017.06.10.a            2017-06-10  2017  Unprovoked             USA
# 3     2017.06.07.R  Reported 07-Jun-2017  2017  Unprovoked  UNITED KINGDOM
# 4       2017.06.04            2017-06-04  2017  Unprovoked             USA
# ...            ...                   ...   ...         ...             ...
# 1152    2008.01.30            2008.01.30  2008    Provoked           JAPAN
# 1153    2008.01.29            2008-01-29  2008  Unprovoked    SOUTH AFRICA
# 1154    2008.01.27            2008-01-27  2008    Provoked       AUSTRALIA
# 1155  2008.01.19.R  Reported 19-Jan-2008  2008     Invalid     NEW ZEALAND
# 1156    2008.01.14            2008-01-14  2008        Boat     NEW ZEALAND
#
# ...

# %%
shark_attack.Species = shark_attack.Species.str.lower()
shark_attack
# Out:
#        Case Number                  Date  Year        Type         Country  \
# 0       2017.06.11            2017-06-11  2017  Unprovoked       AUSTRALIA
# 1     2017.06.10.b            2017-06-10  2017  Unprovoked       AUSTRALIA
# 2     2017.06.10.a            2017-06-10  2017  Unprovoked             USA
# 3     2017.06.07.R  Reported 07-Jun-2017  2017  Unprovoked  UNITED KINGDOM
# 4       2017.06.04            2017-06-04  2017  Unprovoked             USA
# ...            ...                   ...   ...         ...             ...
# 1152    2008.01.30            2008.01.30  2008    Provoked           JAPAN
# 1153    2008.01.29            2008-01-29  2008  Unprovoked    SOUTH AFRICA
# 1154    2008.01.27            2008-01-27  2008    Provoked       AUSTRALIA
# 1155  2008.01.19.R  Reported 19-Jan-2008  2008     Invalid     NEW ZEALAND
# 1156    2008.01.14            2008-01-14  2008        Boat     NEW ZEALAND
#
# ...

# %%
shark_attack.head()
# Out:
#     Case Number                  Date  Year        Type         Country  \
# 0    2017.06.11            2017-06-11  2017  Unprovoked       AUSTRALIA
# 1  2017.06.10.b            2017-06-10  2017  Unprovoked       AUSTRALIA
# 2  2017.06.10.a            2017-06-10  2017  Unprovoked             USA
# 3  2017.06.07.R  Reported 07-Jun-2017  2017  Unprovoked  UNITED KINGDOM
# 4    2017.06.04            2017-06-04  2017  Unprovoked             USA
#
#                 Area                                         Location  \
# 0  Western Australia                         Point Casuarina, Bunbury
# 1           Victoria                   Flinders, Mornington Peninsula
# 2            Florida                      Ponce Inlet, Volusia County
# 3        South Devon                                    Bantham Beach
# 4            Florida  Middle Sambo Reef off Boca Chica, Monroe County
#
#        Activity            Name Sex      Age  \
# 0  Bodyboarding       Paul Goff   M       48
# ...

# %%
from google.colab import files
shark_attack.to_csv("final_project.csv", index=False) 
files.download("final_project.csv")
