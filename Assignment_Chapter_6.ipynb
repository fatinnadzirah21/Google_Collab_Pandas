# %% [markdown]
# <a href="https://colab.research.google.com/github/fatinnadzirah21/Pandas_Google_Colaboratory/blob/main/Assignment_Chapter_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Datasets/GlobalTemperatures.csv")
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
df.rename(columns= {"dt": "Date"}, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8599212 entries, 0 to 8599211
# Data columns (total 7 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Date                           datetime64[ns]
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       object
#  6   Longitude                      object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 459.2+ MB

# %%
df["Date"]=df.Date.astype("datetime64")

# %%
df.head()
# Out:
#         Date  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0 1743-11-01               6.068                          1.737  Århus
# 5 1744-04-01               5.788                          3.624  Århus
# 6 1744-05-01              10.644                          1.283  Århus
# 7 1744-06-01              14.051                          1.347  Århus
# 8 1744-07-01              16.082                          1.396  Århus
#
#    Country        Location
# 0  Denmark  57.05N, 10.33E
# 5  Denmark  57.05N, 10.33E
# 6  Denmark  57.05N, 10.33E
# 7  Denmark  57.05N, 10.33E
# 8  Denmark  57.05N, 10.33E

# %%
df["Location"]=df.Latitude + ", " + df.Longitude

# %%
df.drop(columns=["Latitude", "Longitude"], inplace=True)

# %%
df=df.loc[df.Country.isin(["Australia", "Brazil"])]

# %%
df.sort_values(by=["Date"], ascending=False, inplace=True)
# Out:
#               Date  AverageTemperature  AverageTemperatureUncertainty  \
# 7913009 2013-08-01              13.902                          0.393
# 4431776 2013-08-01              22.807                          0.286
# 7842728 2013-08-01              21.562                          0.337
# 7844909 2013-08-01              22.445                          0.288
# 4479054 2013-08-01              24.351                          1.366
# ...            ...                 ...                            ...
# 1010755 1824-02-01              26.945                          2.103
# 1010754 1824-01-01              27.162                          1.183
# 6746355 1824-01-01              25.962                          1.348
# 4474598 1824-01-01              25.883                          1.263
# 4583179 1824-01-01              26.194                          1.331
#
#                City Country        Location
# 7913009  Uruguaiana  Brazil  29.74S, 57.23W
# ...

# %%
df.head()
# Out:
#               Date  AverageTemperature  AverageTemperatureUncertainty  \
# 7913009 2013-08-01              13.902                          0.393
# 4431776 2013-08-01              22.807                          0.286
# 7842728 2013-08-01              21.562                          0.337
# 7844909 2013-08-01              22.445                          0.288
# 4479054 2013-08-01              24.351                          1.366
#
#                City Country        Location
# 7913009  Uruguaiana  Brazil  29.74S, 57.23W
# 4431776    Luziânia  Brazil  16.87S, 48.56W
# 7842728     Uberaba  Brazil  20.09S, 47.77W
# 7844909  Uberlândia  Brazil  18.48S, 49.01W
# 4479054      Maceió  Brazil  10.45S, 35.18W

# %%
df.to_csv("assignment.csv", index=False)
